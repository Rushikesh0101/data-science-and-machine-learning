# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'car.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df=pd.read_csv(r'car.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
df.columns

# %%
df['normalized-losses']=df['normalized-losses'].replace('?',np.nan).inplace=True
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3               True  alfa-romero       gas  convertible
# 1            3               True  alfa-romero       gas  convertible
# 2            1               True  alfa-romero       gas    hatchback
# 3            2               True         audi       gas        sedan
# 4            2               True         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               True        volvo       gas        sedan
# 201         -1               True        volvo       gas        sedan
# 202         -1               True        volvo       gas        sedan
# 203         -1               True        volvo    diesel        sedan
# 204         -1               True        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df['normalized-losses']=df['normalized-losses'].astype(float)
df['normalized-losses']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 200    1.0
# 201    1.0
# 202    1.0
# 203    1.0
# 204    1.0
# Name: normalized-losses, Length: 205, dtype: float64

# %%
df['horsepower']=df['horsepower'].replace('?',np.nan)
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                1.0  alfa-romero       gas  convertible
# 1            3                1.0  alfa-romero       gas  convertible
# 2            1                1.0  alfa-romero       gas    hatchback
# 3            2                1.0         audi       gas        sedan
# 4            2                1.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1                1.0        volvo       gas        sedan
# 201         -1                1.0        volvo       gas        sedan
# 202         -1                1.0        volvo       gas        sedan
# 203         -1                1.0        volvo    diesel        sedan
# 204         -1                1.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df['horsepower']=df['horsepower'].astype(float)
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                1.0  alfa-romero       gas  convertible
# 1            3                1.0  alfa-romero       gas  convertible
# 2            1                1.0  alfa-romero       gas    hatchback
# 3            2                1.0         audi       gas        sedan
# 4            2                1.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1                1.0        volvo       gas        sedan
# 201         -1                1.0        volvo       gas        sedan
# 202         -1                1.0        volvo       gas        sedan
# 203         -1                1.0        volvo    diesel        sedan
# 204         -1                1.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df['horsepower']=df['horsepower'].fillna(df['horsepower']).mean()
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                1.0  alfa-romero       gas  convertible
# 1            3                1.0  alfa-romero       gas  convertible
# 2            1                1.0  alfa-romero       gas    hatchback
# 3            2                1.0         audi       gas        sedan
# 4            2                1.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1                1.0        volvo       gas        sedan
# 201         -1                1.0        volvo       gas        sedan
# 202         -1                1.0        volvo       gas        sedan
# 203         -1                1.0        volvo    diesel        sedan
# 204         -1                1.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df['normalized-losses']=df['normalized-losses'].fillna(df['normalized-losses']).mean()
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                1.0  alfa-romero       gas  convertible
# 1            3                1.0  alfa-romero       gas  convertible
# 2            1                1.0  alfa-romero       gas    hatchback
# 3            2                1.0         audi       gas        sedan
# 4            2                1.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1                1.0        volvo       gas        sedan
# 201         -1                1.0        volvo       gas        sedan
# 202         -1                1.0        volvo       gas        sedan
# 203         -1                1.0        volvo    diesel        sedan
# 204         -1                1.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
# df.head(200)
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                1.0  alfa-romero       gas  convertible
# 1            3                1.0  alfa-romero       gas  convertible
# 2            1                1.0  alfa-romero       gas    hatchback
# 3            2                1.0         audi       gas        sedan
# 4            2                1.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 195         -1                1.0        volvo       gas        wagon
# 196         -2                1.0        volvo       gas        sedan
# 197         -1                1.0        volvo       gas        wagon
# 198         -2                1.0        volvo       gas        sedan
# 199         -1                1.0        volvo       gas        wagon
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.tail(500)
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                1.0  alfa-romero       gas  convertible
# 1            3                1.0  alfa-romero       gas  convertible
# 2            1                1.0  alfa-romero       gas    hatchback
# 3            2                1.0         audi       gas        sedan
# 4            2                1.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1                1.0        volvo       gas        sedan
# 201         -1                1.0        volvo       gas        sedan
# 202         -1                1.0        volvo       gas        sedan
# 203         -1                1.0        volvo    diesel        sedan
# 204         -1                1.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(7,8))
sns.boxplot(data=df,x='price',y='make')
plt.show()

# %%
df.loc[(df['make']=='isuzu') & (df['price']>20000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0                1.0  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 45           front   63.6    52.0         ohc           90  104.256158
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
df.drop(45,inplace=True)
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                1.0  alfa-romero       gas  convertible
# 1            3                1.0  alfa-romero       gas  convertible
# 2            1                1.0  alfa-romero       gas    hatchback
# 3            2                1.0         audi       gas        sedan
# 4            2                1.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1                1.0        volvo       gas        sedan
# 201         -1                1.0        volvo       gas        sedan
# 202         -1                1.0        volvo       gas        sedan
# 203         -1                1.0        volvo    diesel        sedan
# 204         -1                1.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(7,8))
sns.boxplot(data=df,x='price',y='make')
plt.show()

# %%
df.loc[(df['make']=='honda') & (df['price']>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 41          0                1.0  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 41           front   65.2    54.1         ohc          110  104.256158
#
#     city-mpg  highway-mpg  price
# 41        24           28  12945

# %%
df.drop(41,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df.drop(41,inplace=True)
#       2 df
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(7,8))
sns.boxplot(data=df,x='price',y='make')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 plt.figure(figsize=(7,8))
# ----> 4 sns.boxplot(data=df,x='price',y='make')
#       5 plt.show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # handling categorical data

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'car.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df_cat=df.select_dtypes(object)
df_cat.head(200)
# Out:
#     normalized-losses         make fuel-type   body-style drive-wheels  \
# 0                   ?  alfa-romero       gas  convertible          rwd
# 1                   ?  alfa-romero       gas  convertible          rwd
# 2                   ?  alfa-romero       gas    hatchback          rwd
# 3                 164         audi       gas        sedan          fwd
# 4                 164         audi       gas        sedan          4wd
# ..                ...          ...       ...          ...          ...
# 195                74        volvo       gas        wagon          rwd
# 196               103        volvo       gas        sedan          rwd
# 197                74        volvo       gas        wagon          rwd
# 198               103        volvo       gas        sedan          rwd
# 199                74        volvo       gas        wagon          rwd
#
#     engine-location engine-type horsepower
# 0             front        dohc        111
# ...

# %%
df_num=df.select_dtypes(['float64','int64'])
df_num
# Out:
#      symboling  width  height  engine-size  city-mpg  highway-mpg  price
# 0            3   64.1    48.8          130        21           27  13495
# 1            3   64.1    48.8          130        21           27  16500
# 2            1   65.5    52.4          152        19           26  16500
# 3            2   66.2    54.3          109        24           30  13950
# 4            2   66.4    54.3          136        18           22  17450
# ..         ...    ...     ...          ...       ...          ...    ...
# 200         -1   68.9    55.5          141        23           28  16845
# 201         -1   68.8    55.5          141        19           25  19045
# 202         -1   68.9    55.5          173        18           23  21485
# 203         -1   68.9    55.5          145        26           27  22470
# 204         -1   68.9    55.5          141        19           25  22625
#
# [205 rows x 7 columns]

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    205 non-null    int64
#  1   width        205 non-null    float64
#  2   height       205 non-null    float64
#  3   engine-size  205 non-null    int64
#  4   city-mpg     205 non-null    int64
#  5   highway-mpg  205 non-null    int64
#  6   price        205 non-null    int64
# dtypes: float64(2), int64(5)
# memory usage: 11.3 KB

# %%
df_cat.head(200)
# Out:
#     normalized-losses         make fuel-type   body-style drive-wheels  \
# 0                   ?  alfa-romero       gas  convertible          rwd
# 1                   ?  alfa-romero       gas  convertible          rwd
# 2                   ?  alfa-romero       gas    hatchback          rwd
# 3                 164         audi       gas        sedan          fwd
# 4                 164         audi       gas        sedan          4wd
# ..                ...          ...       ...          ...          ...
# 195                74        volvo       gas        wagon          rwd
# 196               103        volvo       gas        sedan          rwd
# 197                74        volvo       gas        wagon          rwd
# 198               103        volvo       gas        sedan          rwd
# 199                74        volvo       gas        wagon          rwd
#
#     engine-location engine-type horsepower
# 0             front        dohc        111
# ...

# %%
df_cat['fuel-type'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fuel-type, dtype: int64

# %%
#first approach that is one hot encoding to handle categorical data
df_fuel=pd.get_dummies(df_cat['fuel-type'])
df_fuel
# Out:
#      diesel  gas
# 0         0    1
# 1         0    1
# 2         0    1
# 3         0    1
# 4         0    1
# ..      ...  ...
# 200       0    1
# 201       0    1
# 202       0    1
# 203       1    0
# 204       0    1
#
# [205 rows x 2 columns]

# %%
#second approach that is label encoder to handle cateogrical data
#what is scikit learn?
#scikit.learn is an open source machine learning python package that offers functionality
#supporting supervised and unsupervised learning . Additionally it provides tools for model
#development, selection and evaluation as well as many other utilities including data pre-processing funcationality

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df_cat['fuel_type_cat']=le.fit_transform(df_cat['fuel-type'])
df_cat['fuel_type_cat']
#df_cat['make_num']=le.fit_transform(df_cat['make'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 200    1
# 201    1
# 202    1
# 203    0
# 204    1
# Name: fuel_type_cat, Length: 205, dtype: int64

# %%
df_cat
# Out:
#     normalized-losses         make fuel-type   body-style drive-wheels  \
# 0                   ?  alfa-romero       gas  convertible          rwd
# 1                   ?  alfa-romero       gas  convertible          rwd
# 2                   ?  alfa-romero       gas    hatchback          rwd
# 3                 164         audi       gas        sedan          fwd
# 4                 164         audi       gas        sedan          4wd
# ..                ...          ...       ...          ...          ...
# 200                95        volvo       gas        sedan          rwd
# 201                95        volvo       gas        sedan          rwd
# 202                95        volvo       gas        sedan          rwd
# 203                95        volvo    diesel        sedan          rwd
# 204                95        volvo       gas        sedan          rwd
#
#     engine-location engine-type horsepower  fuel_type_cat
# ...

# %%
for i in df_cat:
    le=LabelEncoder()
    df_cat[i]=le.fit_transform(df_cat[i])

# %%
df_cat
# Out:
#      normalized-losses  make  fuel-type  body-style  drive-wheels  \
# 0                   51     0          1           0             2
# 1                   51     0          1           0             2
# 2                   51     0          1           2             2
# 3                   27     1          1           3             1
# 4                   27     1          1           3             0
# ..                 ...   ...        ...         ...           ...
# 200                 49    21          1           3             2
# 201                 49    21          1           3             2
# 202                 49    21          1           3             2
# 203                 49    21          0           3             2
# 204                 49    21          1           3             2
#
#      engine-location  engine-type  horsepower  fuel_type_cat
# 0                  0            0           5              1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %% [markdown]
# # how to remove skewness

# %%
#what is skewness?
#understanding skewness
#besides positive and negative skew, distributions can also be said to have zero or undefinedskew
#in the curve of distribution, the data on the right side of the curve may taper differently from the data
#on the data left side. these taperings are known as "tails." Negative skew refers to a longer or fatter tail on the left side
#of the distribution, while positive skew refers to a longer or fatter tail on the right.

# %% [markdown]
# # scalling

# %%
#MinMaxScaler(feature_range=(0,1)) will transform each value in the column propotionally within the range[0,1].
#use this as the first scaler choice to transform a feature,
#as it will preserve the shape of the dataset (no distribution)

#StandardScaler() will transform each value in the column to range about the mean 0 and the standard  deviation 1,
#ie, each value will be normalised by subtracting the mean and dividing by standard deviation.
#use StandardScalar if you know the data distribution is normal.

#When MinMaxScalar is used the it is also known as Normalization and it transform all the values in range between (0to1)
#formula  is x=[(value - min)/(Max - Min)]

#StandardScalar comes under Standardization and its value ranges between )(-3 to +3)
#formula is z = [(x-x.mean)/Std_deviation]

# %%
from scipy.stats import skew
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print("Skewness",skew(df['height']))
sns.distplot(df['height'])
plt.show()
# Out:
# Skewness 0.06265991683394276
# /tmp/ipykernel_3160/1872416463.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['height'])

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
#ss=StandardScaler()#for positive and negative
#s.fit_transform(df[['height']])
mm=MinMaxScaler()#for positive only
mm.fit_transform(df[['height']])
# Out:
# array([[0.08333333],
#        [0.08333333],
#        [0.38333333],
#        [0.54166667],
#        [0.54166667],
#        [0.44166667],
#        [0.65833333],
#        [0.65833333],
#        [0.675     ],
#        [0.35      ],
#        [0.54166667],
#        [0.54166667],
#        [0.54166667],
#        [0.54166667],
#        [0.65833333],
#        [0.65833333],
#        [0.49166667],
#        [0.70833333],
#        [0.45      ],
#        [0.35      ],
#        [0.35      ],
#        [0.25      ],
#        [0.25      ],
#        [0.25      ],
#        [0.23333333],
#        [0.23333333],
#        [0.23333333],
#        [0.23333333],
#        [1.        ],
#        [0.2       ],
#        [0.25      ],
#        [0.25      ],
#        [0.4       ],
#        [0.4       ],
#        [0.4       ],
#        [0.55833333],
#        [0.875     ],
#        [0.45833333],
#        [0.45833333],
#        [0.525     ],
#        [0.525     ],
#        [0.525     ],
#        [0.26666667],
# ...
